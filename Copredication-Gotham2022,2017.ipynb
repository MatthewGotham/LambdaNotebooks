# %% [markdown]
# # Copredication
#
# This lambda notebook contains a demonstration of some ideas found in the following papers:
#
# - Gotham, Matthew (2022). [Property Inheritance, Deferred Reference and Copredication](https://doi.org/10.1093/jos/ffab020). _Journal of Semantics_ 39(1):87–116.
# - Gotham, Matthew (2017). [Composing Criteria of Individuation in Copredication](http://academic.oup.com//jos/article/doi/10.1093/jos/ffw008/2555474/Composing-Criteria-of-Individuation-in?guestAccessKey=62fb866e-7bd4-47ae-b6b6-cc1be28a5aeb). _Journal of Semantics_ 34(2):333–371.

# %%
# %%lamb
# ||books|| = L x_e: (Books_<e,t>(x), {(x,(L o_(e,e): PHYS_<(e,e),t>(o) & INFO_<(e,e),t>(o)))})
# ||by_CS_Lewis|| = L x_e: (ByLewis_<e,t>(x), {(x,INFO_<(e,e),t>)})
# ||on_the_shelf|| = L x_e: (OnShelf_<e,t>(x), {(x,PHYS_<(e,e),t>)})
# ||MOD|| = L p_<e,(t,{(e,<(e,e),t>)})>: L q_<e,(t,{(e,<(e,e),t>)})>: L x_e: (p(x)[0] & q(x)[0], p(x)[1] | q(x)[1])
# ||three|| = L p_<e,(t,{(e,<(e,e),t>)})>: L q_<e,(t,{(e,<(e,e),t>)})>: ((Exists x_e: Three_<e,t>(x) & p(x)[0] & q(x)[0] & ~Comp_<(e,<(e,e),t>),t>(x,(L u_(e,e): Exists r_<(e,e),t>: (x,r) << (p(x)[1] | q(x)[1]) & r(u)))), (Set a_(e,<(e,e),t>): (Exists y_e: a << p(y)[1] | a << q(y)[1])))
# #& )
# Out:
# ⟦books⟧ = (λ x_e: (Books_<e,t>(x_e), {(x_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e)))))}))
# ⟦by_CS_Lewis⟧ = (λ x_e: (ByLewis_<e,t>(x_e), {(x_e, INFO_<(e,e),t>)}))
# ⟦on_the_shelf⟧ = (λ x_e: (OnShelf_<e,t>(x_e), {(x_e, PHYS_<(e,e),t>)}))
# ⟦MOD⟧ = (λ p_<e,(t,{(e,<(e,e),t>)})>: (λ q_<e,(t,{(e,<(e,e),t>)})>: (λ x_e: (((p_<e,(t,{(e,<(e,e),t>)})>(x_e)[0]) & (q_<e,(t,{(e,<(e,e),t>)})>(x_e)[0])), ((p_<e,(t,{(e,<(e,e),t>)})>(x_e)[1]) | (q_<e,(t,{(e,<(e,e),t>)})>(x_e)[1]))))))
# ⟦three⟧ = (λ p_<e,(t,{(e,<(e,e),t>)})>: (λ q_<e,(t,{(e,<(e,e),t>)})>: ((Exists x_e: (((~Comp_<(e,<(e,e),t>),t>(x_e, (λ u_(e,e): (Exists r_<(e,e),t>: (((x_e, r_<(e,e),t>) << ((p_<e,(t,{(e,<(e,e),t>)})>(x_e)[1]) | (q_<e,(t,{(e,<(e,e),t>)})>(x_e)[1]))) & r_<(e,e),t>(u_(e,e)))))) & Three_<e,t>(x_e)) & (p_<e,(t,{(e,<(e,e),t>)})>(x_e)[0])) & (q_<e,(t,{(e,<(e,e),t>)})>(x_e)[0]))), (Set a_(e,<(e,e),t>): (Exists y_e: ((a_(e,<(e,e),t>) << (p_<e,(t,{(e,<(e,e),t>)})>(y_e)[1])) | (a_(e,<(e,e),t>) << (q_<e,(t,{(e,<(e,e),t>)})>(y_e)[1]))))))))

# %% [markdown]
# (4) There are three books on the shelf.

# %%
((three * books) * on_the_shelf).reduce_all()
# Out:
# 1 composition path.  Result:
#     [0]: ⟦[three books]⟧ * ⟦on_the_shelf⟧ leads to: ⟦[[three books] on_the_shelf]⟧ = ((Exists x_e: (((Books_<e,t>(x_e) & ~Comp_<(e,<(e,e),t>),t>(x_e, (λ u_(e,e): (Exists r_<(e,e),t>: (((x_e, r_<(e,e),t>) << {(x_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e))))), (x_e, PHYS_<(e,e),t>)}) & r_<(e,e),t>(u_(e,e))))))) & OnShelf_<e,t>(x_e)) & Three_<e,t>(x_e))), (Set a_(e,<(e,e),t>): (Exists y_e: ((a_(e,<(e,e),t>) <=> (y_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e)))))) | (a_(e,<(e,e),t>) <=> (y_e, PHYS_<(e,e),t>)))))) [by FA]

# %% [markdown]
# We have to do some of the reduction by hand here:
#
# $$
# \begin{align*}
# \neg Comp(x,&\lambda u_{(e,e)}.\exists r_{\langle(e,e),t\rangle}.((x,r)\in\{(x,(\lambda o_{(e,e)}.INFO(o)\wedge PHYS(o))),(x,PHYS)\})\wedge r(u))) \\
# \Rightarrow\neg Comp(x,&\lambda u_{(e,e)}.\exists r_{\langle(e,e),t\rangle}.(r\in\{(\lambda o_{(e,e)}.INFO(o)\wedge PHYS(o)),PHYS\})\wedge r(u)) \\
# \Rightarrow\neg Comp(x,&\lambda u_{(e,e)}.(INFO(u)\wedge PHYS(u))\vee PHYS(u)) \\
# \Rightarrow\neg Comp(x,&\lambda u_{(e,e)}.PHYS(u)) \\
# \Rightarrow\neg Comp(x,&PHYS)
# \end{align*}
# $$

# %% [markdown]
# (5) There are three books by C.S. Lewis.

# %%
((three * books) * by_CS_Lewis).reduce_all()
# Out:
# 1 composition path.  Result:
#     [0]: ⟦[three books]⟧ * ⟦by_CS_Lewis⟧ leads to: ⟦[[three books] by_CS_Lewis]⟧ = ((Exists x_e: (((Books_<e,t>(x_e) & ByLewis_<e,t>(x_e)) & ~Comp_<(e,<(e,e),t>),t>(x_e, (λ o_(e,e): (Exists r_<(e,e),t>: (((x_e, r_<(e,e),t>) << {(x_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e))))), (x_e, INFO_<(e,e),t>)}) & r_<(e,e),t>(o_(e,e))))))) & Three_<e,t>(x_e))), (Set a_(e,<(e,e),t>): (Exists y_e: ((a_(e,<(e,e),t>) <=> (y_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e)))))) | (a_(e,<(e,e),t>) <=> (y_e, INFO_<(e,e),t>)))))) [by FA]

# %% [markdown]
# (6) There are three books by C.S. Lewis on the shelf.

# %%
((three * ((MOD * by_CS_Lewis) * books)) * on_the_shelf).reduce_all()
# Out:
# 1 composition path.  Result:
#     [0]: ⟦[three [[MOD by_CS_Lewis] books]]⟧ * ⟦on_the_shelf⟧ leads to: ⟦[[three [[MOD by_CS_Lewis] books]] on_the_shelf]⟧ = ((Exists x_e: ((((Books_<e,t>(x_e) & ByLewis_<e,t>(x_e)) & ~Comp_<(e,<(e,e),t>),t>(x_e, (λ o_(e,e): (Exists r_<(e,e),t>: (((x_e, r_<(e,e),t>) << {(x_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e))))), (x_e, PHYS_<(e,e),t>), (x_e, INFO_<(e,e),t>)}) & r_<(e,e),t>(o_(e,e))))))) & OnShelf_<e,t>(x_e)) & Three_<e,t>(x_e))), (Set a_(e,<(e,e),t>): (Exists y_e: ((a_(e,<(e,e),t>) << {(y_e, INFO_<(e,e),t>), (y_e, (λ o_(e,e): (INFO_<(e,e),t>(o_(e,e)) & PHYS_<(e,e),t>(o_(e,e)))))}) | (a_(e,<(e,e),t>) <=> (y_e, PHYS_<(e,e),t>)))))) [by FA]
